# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahfila/MyDocking/blob/main/MyDock_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install pandas

# %%
import pandas as pd

data=pd.read_csv("/content/sample_data/Untitled Folder/5ht1b_3.5m.csv")

# %%
data
# Out:
#                       id                                            smile  \
# 0       ZINC000000002075                  CC(=O)c1ccc2c(c1)C(=O)C1(CC1)O2
# 1       ZINC000000009064  O=C(O)c1cc2cc(O)c(O)cc2c(C(=O)c2ccc(O)c(O)c2)n1
# 2       ZINC000000029328                        CN(C(=O)c1cccnc1)c1ccccc1
# 3       ZINC000000029370                           O=C(NCc1ccccn1)c1cccs1
# 4       ZINC000000029396            O=S(=O)(c1ccccc1)N(Cc1ccccc1)c1ccccn1
# ...                  ...                                              ...
# 167484  ZINC000002518226                   NC(=O)N1c2ccccc2C[C@@H]1C(=O)O
# 167485  ZINC000002522178               Cc1ccccc1C(=O)c1cnn(-c2ccccc2F)c1N
# 167486  ZINC000002522714                              CC(C)OC(=O)C1CCCCC1
# 167487  ZINC000002514150                        CC(C)(C)CC(=O)c1cccc(F)c1
# 167488       ZINC0000025                                              NaN
#
#         docking_score
# 0                -7.7
# 1                -9.6
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined
